# %% [markdown]
# ## Notebook with code dedicated only to preprocess raw data

# %%
import sys
sys.path.append('../')
from source import Translate
from source import Process
from source import Align
# Out:
# /home/tiago/anaconda3/envs/databases/lib/python3.10/site-packages/Bio/Application/__init__.py:39: BiopythonDeprecationWarning: The Bio.Application modules and modules relying on it have been deprecated.
#
# Due to the on going maintenance burden of keeping command line application
# wrappers up to date, we have decided to deprecate and eventually remove these
# modules.
#
# We instead now recommend building your command line and invoking it directly
# with the subprocess module.
#   warnings.warn(

# %% [markdown]
# Insert tags to mark the source of each protein accordingly to its original database

# %%
date = "04052026"

# %%
Translate.ToProtein(
    input = f"../data/raw/megares.{date}.raw.fasta", 
    output = f"../data/filtered/megares.proteins.fasta", 
    minlength = 200)
Translate.ToProtein(
    input = f"../data/raw/resfinder.{date}.raw.fasta", 
    output = f"../data/filtered/resfinder.proteins.fasta", 
    minlength = 200
)

# %%
Process.InsertTag(
    input = f"../data/filtered/megares.proteins.fasta", 
    output = f"../data/filtered/megares.tagged.fasta", 
    tag = "MEGARES"
)
Process.InsertTag(
    input = f"../data/filtered/resfinder.proteins.fasta", 
    output = f"../data/filtered/resfinder.tagged.fasta", 
    tag = "RESFINDER"
)
Process.InsertTag(
    input = f"../data/raw/card.{date}.raw.fasta", 
    output = f"../data/filtered/card.tagged.fasta", 
    tag = "CARD"
)
Process.InsertTag(
    input = f"../data/raw/hmd.21032025.raw.fasta", 
    output = f"../data/filtered/hmd.tagged.fasta", 
    tag = "HMD"
)
Process.InsertTag(
    input = f"../data/raw/ncrd95.21032025.raw.fasta", 
    output = f"../data/filtered/ncrd95.tagged.fasta", 
    tag = "NCRD"
)
Process.InsertTag(
    input = f"../data/raw/ndaro.{date}.raw.fasta", 
    output = f"../data/filtered/ndaro.tagged.fasta", 
    tag = "NDARO"
)

# %%
# !rm ../data/filtered/*.proteins.fasta

# %% [markdown]
# Concatenate all databases into one file

# %%
Process.ConcatenateFiles("../data/filtered/","../data/filtered/AllDatabases.tagged.fasta", "fasta")

# %% [markdown]
# Concatenate all FASTA ids into one file

# %%
Process.ConcatenateFiles("../data/filtered/","../data/filtered/AllDatabases.tagged.fasta_ids","fasta_ids")

# %% [markdown]
# Creates a diamond database

# %%
Process.CreateDatabase("../data/filtered/AllDatabases.tagged.fasta", "../data/filtered/AllDatabases.dmnd")
# Out:
# diamond v2.1.11.165 (C) Max Planck Society for the Advancement of Science, Benjamin Buchfink, University of Tuebingen
# Documentation, support and updates available at http://www.diamondsearch.org
# Please cite: http://dx.doi.org/10.1038/s41592-021-01101-x Nature Methods (2021)
#
# #CPU threads: 12
# Scoring parameters: (Matrix=BLOSUM62 Lambda=0.267 K=0.041 Penalties=11/1)
# Database input file: ../data/filtered/AllDatabases.tagged.fasta
# Opening the database file...  [0.052s]
# Loading sequences...  [0.266s]
# Masking sequences...  [0.112s]
# Writing sequences...  [0.009s]
# Hashing sequences...  [0.004s]
# Loading sequences...  [0s]
# Writing trailer...  [0s]
# Closing the input file...  [0s]
# Closing the database file...  [0.539s]
#
# Database sequences  77149
#   Database letters  25768626
#      Database hash  c71600b9d14addca1ceb77b3029a3b2e
#         Total time  0.985000s

# %%
Process.InsertTag(
    input = "../data/raw/uniprot.21032025.raw.fasta", 
    output = "../data/filtered/uniprot.tagged.fasta", 
    tag = "UNIPROT"
)

# %% [markdown]
# Run diamond to perform pairwise alignment. Essential to create sequence similarity networks

# %%
Align.RunDiamond(
    "../data/filtered/AllDatabases.tagged.fasta", 
    "../data/filtered/AllDatabases.dmnd", 
    "../data/filtered/AllDatabases.Paiwise.cov80.maxseq1.tsv",
    threads = 12,
    maxseq = 1,
    qcov = 80,
    minid = 0
)
# Out:
# Running: diamond blastp -d ../data/filtered/AllDatabases.dmnd -q ../data/filtered/AllDatabases.tagged.fasta -o ../data/filtered/AllDatabases.Paiwise.cov80.maxseq1.tsv -p 12 --id 0 --outfmt 6 qseqid sseqid stitle pident length qlen slen qstart qend sstart send evalue bitscore ppos full_qseq full_sseq -b 0.5 --query-cover 80 -k 1 --no-self-hits
# diamond v2.1.11.165 (C) Max Planck Society for the Advancement of Science, Benjamin Buchfink, University of Tuebingen
# Documentation, support and updates available at http://www.diamondsearch.org
# Please cite: http://dx.doi.org/10.1038/s41592-021-01101-x Nature Methods (2021)
#
# #CPU threads: 12
# Scoring parameters: (Matrix=BLOSUM62 Lambda=0.267 K=0.041 Penalties=11/1)
# Temporary directory: ../data/filtered
# #Target sequences to report alignments for: 1
# Opening the database...  [0.017s]
# Database: ../data/filtered/AllDatabases.dmnd (type: Diamond database, sequences: 77149, letters: 25768626)
# Block size = 500000000
# Opening the input file...  [0.006s]
# Opening the output file...  [0s]
# Loading query sequences...  [0.077s]
# Masking queries...  [0.11s]
# Algorithm: Double-indexed
# Building query histograms...  [0.093s]
# Seeking in database...  [0s]
# Loading reference sequences...  [0.017s]
# Masking reference...  [0.109s]
# Initializing temporary storage...  [0.02s]
# Building reference histograms...  [0.126s]
# Allocating buffers...  [0s]
# Processing query block 1, reference block 1/1, shape 1/2, index chunk 1/4.
# Building reference seed array...  [0.043s]
# Building query seed array...  [0.045s]
# Computing hash join...  [0.027s]
# Masking low complexity seeds...  [0.004s]
# Searching alignments...  [32.4s]
# Deallocating memory...  [0s]
# Processing query block 1, reference block 1/1, shape 1/2, index chunk 2/4.
# Building reference seed array...  [0.05s]
# Building query seed array...  [0.049s]
# Computing hash join...  [0.026s]
# Masking low complexity seeds...  [0.004s]
# Searching alignments...  [24.818s]
# Deallocating memory...  [0s]
# Processing query block 1, reference block 1/1, shape 1/2, index chunk 3/4.
# Building reference seed array...  [0.045s]
# Building query seed array...  [0.044s]
# Computing hash join...  [0.027s]
# Masking low complexity seeds...  [0.004s]
# Searching alignments...  [18.657s]
# Deallocating memory...  [0s]
# Processing query block 1, reference block 1/1, shape 1/2, index chunk 4/4.
# Building reference seed array...  [0.037s]
# Building query seed array...  [0.037s]
# Computing hash join...  [0.027s]
# Masking low complexity seeds...  [0.004s]
# Searching alignments...  [17.681s]
# Deallocating memory...  [0s]
# Processing query block 1, reference block 1/1, shape 2/2, index chunk 1/4.
# Building reference seed array...  [0.04s]
# Building query seed array...  [0.039s]
# Computing hash join...  [0.026s]
# Masking low complexity seeds...  [0.004s]
# Searching alignments...  [21.766s]
# Deallocating memory...  [0s]
# Processing query block 1, reference block 1/1, shape 2/2, index chunk 2/4.
# Building reference seed array...  [0.049s]
# Building query seed array...  [0.05s]
# Computing hash join...  [0.026s]
# Masking low complexity seeds...  [0.005s]
# Searching alignments...  [19.251s]
# Deallocating memory...  [0s]
# Processing query block 1, reference block 1/1, shape 2/2, index chunk 3/4.
# Building reference seed array...  [0.044s]
# Building query seed array...  [0.044s]
# Computing hash join...  [0.026s]
# Masking low complexity seeds...  [0.004s]
# Searching alignments...  [17.425s]
# Deallocating memory...  [0s]
# Processing query block 1, reference block 1/1, shape 2/2, index chunk 4/4.
# Building reference seed array...  [0.041s]
# Building query seed array...  [0.04s]
# Computing hash join...  [0.026s]
# Masking low complexity seeds...  [0.004s]
# Searching alignments...  [17.748s]
# Deallocating memory...  [0s]
# Deallocating buffers...  [0s]
# Clearing query masking...  [0.002s]
# Computing alignments...  [163.601s]
# Deallocating reference...  [0s]
# Loading reference sequences...  [0s]
# Deallocating buffers...  [0s]
# Deallocating queries...  [0s]
# Loading query sequences...  [0s]
# Closing the input file...  [0s]
# Closing the output file...  [1.033s]
# Closing the database...  [0s]
# Cleaning up...  [0s]
# Total time = 335.936s
# Reported 76573 pairwise alignments, 76573 HSPs.
# 76573 queries aligned.
# DIAMOND blastp output saved to: ../data/filtered/AllDatabases.Paiwise.cov80.maxseq1.tsv

# %%
Align.RunDiamond(
    "../data/filtered/AllDatabases.tagged.fasta", 
    "../data/filtered/AllDatabases.dmnd", 
    "../data/filtered/AllDatabases.Paiwise.cov80.maxseq5.tsv",
    threads = 12,
    maxseq = 5,
    qcov = 80,
    minid = 0
)
# Out:
# Running: diamond blastp -d ../data/filtered/AllDatabases.dmnd -q ../data/filtered/AllDatabases.tagged.fasta -o ../data/filtered/AllDatabases.Paiwise.cov80.maxseq5.tsv -p 12 --id 0 --outfmt 6 qseqid sseqid stitle pident length qlen slen qstart qend sstart send evalue bitscore ppos full_qseq full_sseq -b 0.5 --query-cover 80 -k 5 --no-self-hits
# diamond v2.1.11.165 (C) Max Planck Society for the Advancement of Science, Benjamin Buchfink, University of Tuebingen
# Documentation, support and updates available at http://www.diamondsearch.org
# Please cite: http://dx.doi.org/10.1038/s41592-021-01101-x Nature Methods (2021)
#
# #CPU threads: 12
# Scoring parameters: (Matrix=BLOSUM62 Lambda=0.267 K=0.041 Penalties=11/1)
# Temporary directory: ../data/filtered
# #Target sequences to report alignments for: 5
# Opening the database...  [0.024s]
# Database: ../data/filtered/AllDatabases.dmnd (type: Diamond database, sequences: 77149, letters: 25768626)
# Block size = 500000000
# Opening the input file...  [0.006s]
# Opening the output file...  [0.001s]
# Loading query sequences...  [0.078s]
# Masking queries...  [0.11s]
# Algorithm: Double-indexed
# Building query histograms...  [0.096s]
# Seeking in database...  [0s]
# Loading reference sequences...  [0.016s]
# Masking reference...  [0.108s]
# Initializing temporary storage...  [0.02s]
# Building reference histograms...  [0.127s]
# Allocating buffers...  [0s]
# Processing query block 1, reference block 1/1, shape 1/2, index chunk 1/4.
# Building reference seed array...  [0.044s]
# Building query seed array...  [0.045s]
# Computing hash join...  [0.027s]
# Masking low complexity seeds...  [0.004s]
# Searching alignments...  [32.607s]
# Deallocating memory...  [0s]
# Processing query block 1, reference block 1/1, shape 1/2, index chunk 2/4.
# Building reference seed array...  [0.048s]
# Building query seed array...  [0.049s]
# Computing hash join...  [0.027s]
# Masking low complexity seeds...  [0.005s]
# Searching alignments...  [24.522s]
# Deallocating memory...  [0s]
# Processing query block 1, reference block 1/1, shape 1/2, index chunk 3/4.
# Building reference seed array...  [0.047s]
# Building query seed array...  [0.044s]
# Computing hash join...  [0.028s]
# Masking low complexity seeds...  [0.004s]
# Searching alignments...  [18.473s]
# Deallocating memory...  [0s]
# Processing query block 1, reference block 1/1, shape 1/2, index chunk 4/4.
# Building reference seed array...  [0.04s]
# Building query seed array...  [0.04s]
# Computing hash join...  [0.028s]
# Masking low complexity seeds...  [0.004s]
# Searching alignments...  [17.816s]
# Deallocating memory...  [0s]
# Processing query block 1, reference block 1/1, shape 2/2, index chunk 1/4.
# Building reference seed array...  [0.036s]
# Building query seed array...  [0.039s]
# Computing hash join...  [0.027s]
# Masking low complexity seeds...  [0.004s]
# Searching alignments...  [21.534s]
# Deallocating memory...  [0s]
# Processing query block 1, reference block 1/1, shape 2/2, index chunk 2/4.
# Building reference seed array...  [0.045s]
# Building query seed array...  [0.052s]
# Computing hash join...  [0.027s]
# Masking low complexity seeds...  [0.004s]
# Searching alignments...  [19.227s]
# Deallocating memory...  [0s]
# Processing query block 1, reference block 1/1, shape 2/2, index chunk 3/4.
# Building reference seed array...  [0.041s]
# Building query seed array...  [0.045s]
# Computing hash join...  [0.027s]
# Masking low complexity seeds...  [0.004s]
# Searching alignments...  [17.485s]
# Deallocating memory...  [0s]
# Processing query block 1, reference block 1/1, shape 2/2, index chunk 4/4.
# Building reference seed array...  [0.041s]
# Building query seed array...  [0.039s]
# Computing hash join...  [0.027s]
# Masking low complexity seeds...  [0.005s]
# Searching alignments...  [17.322s]
# Deallocating memory...  [0s]
# Deallocating buffers...  [0s]
# Clearing query masking...  [0.001s]
# Computing alignments...  [166.486s]
# Deallocating reference...  [0s]
# Loading reference sequences...  [0s]
# Deallocating buffers...  [0s]
# Deallocating queries...  [0s]
# Loading query sequences...  [0s]
# Closing the input file...  [0s]
# Closing the output file...  [0.638s]
# Closing the database...  [0s]
# Cleaning up...  [0s]
# Total time = 337.731s
# Reported 380754 pairwise alignments, 380754 HSPs.
# 76573 queries aligned.
# DIAMOND blastp output saved to: ../data/filtered/AllDatabases.Paiwise.cov80.maxseq5.tsv
