# %% [markdown]
# ## Notebook with code dedicated only to preprocess raw data

# %%
import sys
sys.path.append('../')
import subprocess
from source import Translate
from source import Process
from source import Align
# Out:
# /home/tiago/anaconda3/envs/databases/lib/python3.10/site-packages/Bio/Application/__init__.py:39: BiopythonDeprecationWarning: The Bio.Application modules and modules relying on it have been deprecated.
#
# Due to the on going maintenance burden of keeping command line application
# wrappers up to date, we have decided to deprecate and eventually remove these
# modules.
#
# We instead now recommend building your command line and invoking it directly
# with the subprocess module.
#   warnings.warn(

# %%
Translate.ToProtein(
    input = "../data/raw/megares.21032025.raw.fasta", 
    output = "../data/filtered/megares.21032025.proteins.fasta", 
    minlength = 200)
Translate.ToProtein(
    input = "../data/raw/resfinder.21032025.raw.fasta", 
    output = "../data/filtered/resfinder.21032025.proteins.fasta", 
    minlength = 200
)

# %%
Process.InsertTag(
    input = "../data/filtered/megares.21032025.proteins.fasta", 
    output = "../data/filtered/megares.21032025.tagged.fasta", 
    tag = "MEGARES"
)

Process.InsertTag(
    input = "../data/filtered/resfinder.21032025.proteins.fasta", 
    output = "../data/filtered/resfinder.21032025.tagged.fasta", 
    tag = "RESFINDER"
)

Process.InsertTag(
    input = "../data/raw/card.21032025.raw.fasta", 
    output = "../data/filtered/card.21032025.tagged.fasta", 
    tag = "CARD"
)
Process.InsertTag(
    input = "../data/raw/hmd.21032025.raw.fasta", 
    output = "../data/filtered/hmd.21032025.tagged.fasta", 
    tag = "HMD"
)
Process.InsertTag(
    input = "../data/raw/ncrd95.21032025.raw.fasta", 
    output = "../data/filtered/ncrd95.21032025.tagged.fasta", 
    tag = "NCRD"
)
Process.InsertTag(
    input = "../data/raw/ndaro.21032025.raw.fasta", 
    output = "../data/filtered/ndaro.21032025.tagged.fasta", 
    tag = "NDARO"
)

# %%
# !rm ../data/filtered/*.proteins.fasta

# %%
Process.ConcatenateFiles("../data/filtered/","../data/filtered/AllDatabases.21032025.tagged.fasta", "fasta")

# %%
Process.ConcatenateFiles("../data/filtered/","../data/filtered/AllDatabases.21032025.tagged.fasta_ids","fasta_ids")

# %%
Process.CreateDatabase("../data/filtered/AllDatabases.21032025.tagged.fasta", "../data/filtered/AllDatabases.21032025.dmnd")
# Out:
# diamond v2.1.11.165 (C) Max Planck Society for the Advancement of Science, Benjamin Buchfink, University of Tuebingen
# Documentation, support and updates available at http://www.diamondsearch.org
# Please cite: http://dx.doi.org/10.1038/s41592-021-01101-x Nature Methods (2021)
#
# #CPU threads: 12
# Scoring parameters: (Matrix=BLOSUM62 Lambda=0.267 K=0.041 Penalties=11/1)
# Database input file: ../data/filtered/AllDatabases.21032025.tagged.fasta
# Opening the database file...  [0.051s]
# Loading sequences...  [0.239s]
# Masking sequences...  [0.116s]
# Writing sequences...  [0.009s]
# Hashing sequences...  [0.006s]
# Loading sequences...  [0s]
# Writing trailer...  [0s]
# Closing the input file...  [0s]
# Closing the database file...  [0.441s]
#
# Database sequences  74478
#   Database letters  24639129
#      Database hash  9491df8fd9b861658bc0edfc9796de61
#         Total time  0.865000s

# %%
Process.InsertTag(
    input = "../data/raw/uniprot.21032025.raw.fasta", 
    output = "../data/filtered/uniprot.21032025.tagged.fasta", 
    tag = "UNIPROT"
)

# %%
Align.RunDiamond(
    "../data/filtered/AllDatabases.21032025.tagged.fasta", 
    "../data/filtered/AllDatabases.21032025.dmnd", 
    "../data/filtered/AllDatabases.Paiwise.cov80.maxseq1.tsv",
    threads = 12,
    maxseq = 1
)
# Out:
# diamond v2.1.11.165 (C) Max Planck Society for the Advancement of Science, Benjamin Buchfink, University of Tuebingen
# Documentation, support and updates available at http://www.diamondsearch.org
# Please cite: http://dx.doi.org/10.1038/s41592-021-01101-x Nature Methods (2021)
#
# #CPU threads: 12
# Scoring parameters: (Matrix=BLOSUM62 Lambda=0.267 K=0.041 Penalties=11/1)
# Temporary directory: ../data/filtered
# #Target sequences to report alignments for: 1
# Opening the database...  [0.019s]
# Database: ../data/filtered/AllDatabases.21032025.dmnd (type: Diamond database, sequences: 74478, letters: 24639129)
# Block size = 4000000000
# Opening the input file...  [0.009s]
# Opening the output file...  [0s]
# Loading query sequences...  [0.084s]
# Masking queries...  [0.118s]
# Algorithm: Double-indexed
# Building query histograms...  [0.112s]
# Seeking in database...  [0s]
# Loading reference sequences...  [0.021s]
# Masking reference...  [0.114s]
# Initializing temporary storage...  [0.038s]
# Building reference histograms...  [0.113s]
# Allocating buffers...  [0s]
# Processing query block 1, reference block 1/1, shape 1/2, index chunk 1/4.
# Building reference seed array...  [0.047s]
# Building query seed array...  [0.049s]
# Computing hash join...  [0.032s]
# Masking low complexity seeds...  [0.005s]
# Searching alignments...  [32.827s]
# Deallocating memory...  [0s]
# Processing query block 1, reference block 1/1, shape 1/2, index chunk 2/4.
# Building reference seed array...  [0.059s]
# Building query seed array...  [0.058s]
# Computing hash join...  [0.034s]
# Masking low complexity seeds...  [0.006s]
# Searching alignments...  [24.109s]
# Deallocating memory...  [0s]
# Processing query block 1, reference block 1/1, shape 1/2, index chunk 3/4.
# Building reference seed array...  [0.056s]
# Building query seed array...  [0.056s]
# Computing hash join...  [0.038s]
# Masking low complexity seeds...  [0.007s]
# Searching alignments...  [18.788s]
# Deallocating memory...  [0s]
# Processing query block 1, reference block 1/1, shape 1/2, index chunk 4/4.
# Building reference seed array...  [0.042s]
# Building query seed array...  [0.039s]
# Computing hash join...  [0.035s]
# Masking low complexity seeds...  [0.005s]
# Searching alignments...  [17.487s]
# Deallocating memory...  [0s]
# Processing query block 1, reference block 1/1, shape 2/2, index chunk 1/4.
# Building reference seed array...  [0.035s]
# Building query seed array...  [0.042s]
# Computing hash join...  [0.035s]
# Masking low complexity seeds...  [0.006s]
# Searching alignments...  [21.856s]
# Deallocating memory...  [0s]
# Processing query block 1, reference block 1/1, shape 2/2, index chunk 2/4.
# Building reference seed array...  [0.061s]
# Building query seed array...  [0.065s]
# Computing hash join...  [0.035s]
# Masking low complexity seeds...  [0.006s]
# Searching alignments...  [19.174s]
# Deallocating memory...  [0s]
# Processing query block 1, reference block 1/1, shape 2/2, index chunk 3/4.
# Building reference seed array...  [0.054s]
# Building query seed array...  [0.058s]
# Computing hash join...  [0.035s]
# Masking low complexity seeds...  [0.005s]
# Searching alignments...  [17.165s]
# Deallocating memory...  [0s]
# Processing query block 1, reference block 1/1, shape 2/2, index chunk 4/4.
# Building reference seed array...  [0.058s]
# Building query seed array...  [0.051s]
# Computing hash join...  [0.036s]
# Masking low complexity seeds...  [0.005s]
# Searching alignments...  [17.284s]
# Deallocating memory...  [0s]
# Deallocating buffers...  [0.003s]
# Clearing query masking...  [0.002s]
# Computing alignments...  [161.271s]
# Deallocating reference...  [0.001s]
# Loading reference sequences...  [0s]
# Deallocating buffers...  [0s]
# Deallocating queries...  [0s]
# Loading query sequences...  [0s]
# Closing the input file...  [0s]
# Closing the output file...  [0.847s]
# Closing the database...  [0.001s]
# Cleaning up...  [0s]
# Total time = 332.637s
# Reported 74160 pairwise alignments, 74160 HSPs.
# 74160 queries aligned.
